# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../data/first_v_Hotel Reservations.csv')

# %%
df.head(20)
# Out:
#    Booking_ID  no_of_adults  no_of_children  no_of_weekend_nights  \
# 0    INN00001             2               0                     1
# 1    INN00002             2               0                     2
# 2    INN00003             1               0                     2
# 3    INN00004             2               0                     0
# 4    INN00005             2               0                     1
# 5    INN00006             2               0                     0
# 6    INN00007             2               0                     1
# 7    INN00008             2               0                     1
# 8    INN00009             3               0                     0
# 9    INN00010             2               0                     0
# 10   INN00011             1               0                     1
# 11   INN00012             1               0                     2
# 12   INN00013             2               0                     2
# ...

# %%
df['booking_status'].value_counts()
# Out:
# booking_status
# Not_Canceled    24390
# Canceled        11885
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['Booking_ID', 'no_of_adults', 'no_of_children', 'no_of_weekend_nights',
#        'no_of_week_nights', 'type_of_meal_plan', 'required_car_parking_space',
#        'room_type_reserved', 'lead_time', 'arrival_year', 'arrival_month',
#        'arrival_date', 'market_segment_type', 'repeated_guest',
#        'no_of_previous_cancellations', 'no_of_previous_bookings_not_canceled',
#        'avg_price_per_room', 'no_of_special_requests', 'booking_status',
#        'date'],
#       dtype='object')

# %%
df['market_segment_type'] = df['market_segment_type'].replace(['Aviation', 'Complementary','Corporate'], 'Others')
df['market_segment_type'].unique()
# Out:
# array(['Offline', 'Online', 'Others'], dtype=object)

# %%
new_df = pd.DataFrame()
for i in ["no_of_adults","no_of_children","no_of_weekend_nights","no_of_week_nights","required_car_parking_space","lead_time","arrival_year","arrival_month","arrival_date","repeated_guest","no_of_previous_cancellations","no_of_previous_bookings_not_canceled","avg_price_per_room","no_of_special_requests"]:
    new_df.insert(0,i,df[i].values)

# %%
n = []
for i in new_df["avg_price_per_room"]:
    n.append(int(i))
new_df["avg_price_per_room"] = n

# %%
plt.figure(figsize = (15,8))

sns.heatmap(new_df.corr(),annot=True)
plt.savefig('heatmap.png',bbox_inches='tight')

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# Booking_ID                               0
# no_of_adults                             0
# no_of_children                           0
# no_of_weekend_nights                     0
# no_of_week_nights                        0
# type_of_meal_plan                        0
# required_car_parking_space               0
# room_type_reserved                       0
# lead_time                                0
# arrival_year                             0
# arrival_month                            0
# arrival_date                             0
# market_segment_type                      0
# repeated_guest                           0
# no_of_previous_cancellations             0
# no_of_previous_bookings_not_canceled     0
# avg_price_per_room                       0
# no_of_special_requests                   0
# booking_status                           0
# date                                    37
# dtype: int64

# %%
df.isna().sum()
# Out:
# Booking_ID                               0
# no_of_adults                             0
# no_of_children                           0
# no_of_weekend_nights                     0
# no_of_week_nights                        0
# type_of_meal_plan                        0
# required_car_parking_space               0
# room_type_reserved                       0
# lead_time                                0
# arrival_year                             0
# arrival_month                            0
# arrival_date                             0
# market_segment_type                      0
# repeated_guest                           0
# no_of_previous_cancellations             0
# no_of_previous_bookings_not_canceled     0
# avg_price_per_room                       0
# no_of_special_requests                   0
# booking_status                           0
# date                                    37
# dtype: int64

# %%
df.columns
# Out:
# Index(['Booking_ID', 'no_of_adults', 'no_of_children', 'no_of_weekend_nights',
#        'no_of_week_nights', 'type_of_meal_plan', 'required_car_parking_space',
#        'room_type_reserved', 'lead_time', 'arrival_year', 'arrival_month',
#        'arrival_date', 'market_segment_type', 'repeated_guest',
#        'no_of_previous_cancellations', 'no_of_previous_bookings_not_canceled',
#        'avg_price_per_room', 'no_of_special_requests', 'booking_status',
#        'date'],
#       dtype='object')

# %%
df['type_of_meal_plan'].unique()
# Out:
# array(['Meal Plan 1', 'Not Selected', 'Meal Plan 2', 'Meal Plan 3'],
#       dtype=object)

# %%
pd.set_option('display.max_columns', None)
df.head()
# Out:
#   Booking_ID  no_of_adults  no_of_children  no_of_weekend_nights  \
# 0   INN00001             2               0                     1
# 1   INN00002             2               0                     2
# 2   INN00003             1               0                     2
# 3   INN00004             2               0                     0
# 4   INN00005             2               0                     1
#
#    no_of_week_nights type_of_meal_plan  required_car_parking_space  \
# 0                  2       Meal Plan 1                           0
# 1                  3      Not Selected                           0
# 2                  1       Meal Plan 1                           0
# 3                  2       Meal Plan 1                           0
# 4                  1      Not Selected                           0
#
#   room_type_reserved  lead_time arrival_year arrival_month arrival_date  \
# 0        Room_Type 1        224         2017            10            2
# ...

# %%
# le = LabelEncoder()

# %%
df['type_of_meal_plan_num'] = le.fit_transform(df['type_of_meal_plan'])

# %%
df['room_type_reserved_num'] = le.fit_transform(df['room_type_reserved'])

# %%
df['room_type_reserved_num'].value_counts()
# Out:
# room_type_reserved_num
# 0    28130
# 3     6057
# 5      966
# 1      692
# 4      265
# 6      158
# 2        7
# Name: count, dtype: int64

# %%
df['market_segment_type_num'] = le.fit_transform(df['market_segment_type'])

# %%
df['booking_status_num'] = le.fit_transform(df['booking_status'])

# %%
df.to_csv('../data/Hotel Reservations.csv')

# %%
df['no_of_previous_cancellations'].value_counts()
# Out:
# no_of_previous_cancellations
# 0     35937
# 1       198
# 2        46
# 3        43
# 11       25
# 5        11
# 4        10
# 13        4
# 6         1
# Name: count, dtype: int64

# %%
df['arrival_date'] = df['arrival_date'].astype(str)
df['arrival_month'] = df['arrival_month'].astype(str)
df['arrival_year'] = df['arrival_year'].astype(str)


df['date'] = df['arrival_year'] + '-' + df['arrival_month'] + '-' + df['arrival_date']

# %%
df['date'] = pd.to_datetime(df['date'], format='%Y-%m-%d', errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36275 entries, 0 to 36274
# Data columns (total 20 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Booking_ID                            36275 non-null  object
#  1   no_of_adults                          36275 non-null  int64
#  2   no_of_children                        36275 non-null  int64
#  3   no_of_weekend_nights                  36275 non-null  int64
#  4   no_of_week_nights                     36275 non-null  int64
#  5   type_of_meal_plan                     36275 non-null  object
#  6   required_car_parking_space            36275 non-null  int64
#  7   room_type_reserved                    36275 non-null  object
#  8   lead_time                             36275 non-null  int64
#  9   arrival_year                          36275 non-null  object
#  10  arrival_month                         36275 non-null  object
# ...

# %%
df.head()
# Out:
#   Booking_ID  no_of_adults  no_of_children  no_of_weekend_nights  \
# 0   INN00001             2               0                     1
# 1   INN00002             2               0                     2
# 2   INN00003             1               0                     2
# 3   INN00004             2               0                     0
# 4   INN00005             2               0                     1
#
#    no_of_week_nights type_of_meal_plan  required_car_parking_space  \
# 0                  2       Meal Plan 1                           0
# 1                  3      Not Selected                           0
# 2                  1       Meal Plan 1                           0
# 3                  2       Meal Plan 1                           0
# 4                  1      Not Selected                           0
#
#   room_type_reserved  lead_time arrival_year arrival_month arrival_date  \
# 0        Room_Type 1        224         2017            10            2
# ...

# %%
custom_palette = ['#76B7B2','#E15759' ]

sns.kdeplot(data=df, x="no_of_adults", hue="booking_status", multiple="stack", palette=custom_palette)
plt.savefig('kdeadults.png',bbox_inches='tight')
# Out:
# /Users/sheyda/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /var/folders/1n/7pvyp0kj0w310_hltg5yby980000gn/T/ipykernel_18473/336717900.py:3: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.kdeplot(data=df, x="no_of_adults", multiple="stack", palette=custom_palette)
# /Users/sheyda/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.kdeplot(data=df, x="no_of_children", multiple="stack", palette=custom_palette)
plt.savefig('kdechild.png',bbox_inches='tight')
# Out:
# /Users/sheyda/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /var/folders/1n/7pvyp0kj0w310_hltg5yby980000gn/T/ipykernel_18473/1914940656.py:1: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.kdeplot(data=df, x="no_of_children", multiple="stack", palette=custom_palette)
# /Users/sheyda/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
df.groupby('booking_status')['avg_price_per_room'].mean()
# Out:
# booking_status
# Canceled        110.589966
# Not_Canceled     99.931412
# Name: avg_price_per_room, dtype: float64

# %%
# sns.kdeplot(data=df, x="no_of_previous_cancellations", y="no_of_previous_bookings_not_canceled", cmap="viridis", fill=True)

# # Add a 2D scatter plot with count information
# sns.scatterplot(data=df, x="no_of_previous_cancellations", y="no_of_previous_bookings_not_canceled", size=10, marker="o", color="red")

# %%
df.to_csv('../data/Hotel Reservations.csv')

# %%
jnt = sns.jointplot(data=df, x='lead_time', y='avg_price_per_room', 
              hue='booking_status', alpha=0.75, palette = 'magma')

# %%
sns.pairplot(df[['lead_time','booking_status','avg_price_per_room','market_segment_type']], hue="booking_status")

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
from matplotlib.colors import LinearSegmentedColormap
import seaborn as sns 
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import MinMaxScaler 

from sklearn.metrics import roc_curve, roc_auc_score, confusion_matrix, ConfusionMatrixDisplay, accuracy_score, auc #Metrics
mean_price_canceled = df[df['booking_status'] == True]['avg_price_per_room'].mean()
mean_price_not_canceled = df[df['booking_status'] == False]['avg_price_per_room'].mean()

# %%
sns.histplot(data=df, x='avg_price_per_room', hue='booking_status')

mean_price_canceled = df[df['booking_status'] == 'Canceled']['avg_price_per_room'].mean()
mean_price_not_canceled = df[df['booking_status'] == 'Not_Canceled']['avg_price_per_room'].mean()

plt.axvline(x=mean_price_canceled, color='red', label=f'Avg Price Canceled: {mean_price_canceled:.2f}')
plt.axvline(x=mean_price_not_canceled, color='green', label=f'Avg Price Not Canceled: {mean_price_not_canceled:.2f}')

plt.text(150, 1000, f'Avg Price Canceled: {mean_price_canceled:.2f}$', fontname='Roboto', fontstyle='italic')
plt.text(120, 1200, f'Avg Price Not Canceled: {mean_price_not_canceled:.2f}$', fontname='Roboto', fontstyle='italic')

plt.legend(loc='center right')

plt.savefig('cancel-price.png',bbox_inches='tight')

# %%
df['no_of_previous_cancellations'].value_counts()
# Out:
# no_of_previous_cancellations
# 0     35937
# 1       198
# 2        46
# 3        43
# 11       25
# 5        11
# 4        10
# 13        4
# 6         1
# Name: count, dtype: int64

# %%
df['no_of_previous_bookings_not_canceled'].value_counts()
# Out:
# no_of_previous_bookings_not_canceled
# 0     35463
# 1       228
# 2       112
# 3        80
# 4        65
# 5        60
# 6        36
# 7        24
# 8        23
# 10       19
# 9        19
# 11       15
# 12       12
# 14        9
# 15        8
# 16        7
# 13        7
# 18        6
# 20        6
# 21        6
# 17        6
# 19        6
# 22        6
# 25        3
# 27        3
# 24        3
# 23        3
# 44        2
# 29        2
# 48        2
# 28        2
# 30        2
# 32        2
# 31        2
# 26        2
# 46        1
# 55        1
# 45        1
# 57        1
# 53        1
# 54        1
# 58        1
# 41        1
# 40        1
# 43        1
# 35        1
# 50        1
# 56        1
# 33        1
# 37        1
# 42        1
# 51        1
# 38        1
# 34        1
# 39        1
# 52        1
# 49        1
# 47        1
# 36        1
# Name: count, dtype: int64

# %%
df[(df['repeated_guest'] == 0)]
# Out:
#       Booking_ID  no_of_adults  no_of_children  no_of_weekend_nights  \
# 0       INN00001             2               0                     1
# 1       INN00002             2               0                     2
# 2       INN00003             1               0                     2
# 3       INN00004             2               0                     0
# 4       INN00005             2               0                     1
# ...          ...           ...             ...                   ...
# 36270   INN36271             3               0                     2
# 36271   INN36272             2               0                     1
# 36272   INN36273             2               0                     2
# 36273   INN36274             2               0                     0
# 36274   INN36275             2               0                     1
#
#        no_of_week_nights type_of_meal_plan  required_car_parking_space  \
# ...

# %%
df['no_of_adults'].sum()
# Out:
# 66926

# %%
df['no_of_children'].value_counts()
# Out:
# no_of_children
# 0     33577
# 1      1618
# 2      1058
# 3        19
# 9         2
# 10        1
# Name: count, dtype: int64

# %%
df['no_of_adults'].value_counts()
# Out:
# no_of_adults
# 2    26108
# 1     7695
# 3     2317
# 0      139
# 4       16
# Name: count, dtype: int64

# %%
df[df['avg_price_per_room'] == 1]
# Out:
#       Booking_ID  no_of_adults  no_of_children  no_of_weekend_nights  \
# 165     INN00166             1               0                     2
# 1425    INN01426             1               0                     0
# 5490    INN05491             2               0                     0
# 10213   INN10214             1               0                     1
# 13223   INN13224             2               0                     0
# 14981   INN14982             1               0                     2
# 24189   INN24190             1               0                     0
# 35467   INN35468             1               0                     0
# 36263   INN36264             1               0                     2
#
#        no_of_week_nights type_of_meal_plan  required_car_parking_space  \
# 165                    1       Meal Plan 2                           0
# 1425                   2       Meal Plan 2                           0
# ...

# %%
df['no_of_adults'].sum()
# Out:
# 66926

# %%
df['no_of_children'].sum()
# Out:
# 3819

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, classification_report

# %%
features = df[['no_of_adults', 'no_of_children', 'no_of_weekend_nights',
       'no_of_week_nights', 'type_of_meal_plan_num', 'required_car_parking_space',
       'room_type_reserved_num', 'lead_time', 'arrival_year', 'arrival_month',
       'arrival_date', 'market_segment_type_num', 'repeated_guest',
       'no_of_previous_cancellations', 'no_of_previous_bookings_not_canceled']]
target = df['booking_status']

# %%
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=42)

# %%
model = DecisionTreeClassifier()

# %%
model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
predictions = model.predict(X_test)

accuracy = accuracy_score(y_test, predictions)
report = classification_report(y_test, predictions)

print("Accuracy:", accuracy)
print("Classification Report:\n", report)
# Out:
# Accuracy: 0.8048242591316334
# Classification Report:
#                precision    recall  f1-score   support
#
#     Canceled       0.70      0.72      0.71      2416
# Not_Canceled       0.86      0.85      0.85      4839
#
#     accuracy                           0.80      7255
#    macro avg       0.78      0.78      0.78      7255
# weighted avg       0.81      0.80      0.81      7255

# %%
new_reservation_features = {
    'no_of_adults': 2,
    'no_of_children': 0,
    'no_of_weekend_nights': 2,
    'no_of_week_nights': 2,
    'type_of_meal_plan_num': 0,  
    'required_car_parking_space': 0, 
    'room_type_reserved_num': 0, 
    'lead_time': 150,
    'arrival_year': 2024,
    'arrival_month': 10,
    'arrival_date': 15,
    'market_segment_type_num': 1, 
    'repeated_guest': 0,
    'no_of_previous_cancellations': 0,
    'no_of_previous_bookings_not_canceled': 0
}

new_reservation_df = pd.DataFrame([new_reservation_features])

prediction = model.predict(new_reservation_df)

print("Prediction for the new reservation:", prediction[0])
# Out:
# Prediction for the new reservation: Not_Canceled

# %%
df.head(100)
# Out:
#    Booking_ID  no_of_adults  no_of_children  no_of_weekend_nights  \
# 0    INN00001             2               0                     1
# 1    INN00002             2               0                     2
# 2    INN00003             1               0                     2
# 3    INN00004             2               0                     0
# 4    INN00005             2               0                     1
# ..        ...           ...             ...                   ...
# 95   INN00096             2               1                     0
# 96   INN00097             2               0                     0
# 97   INN00098             2               0                     0
# 98   INN00099             2               0                     0
# 99   INN00100             2               2                     1
#
#     no_of_week_nights type_of_meal_plan  required_car_parking_space  \
# 0                   2       Meal Plan 1                           0
# ...
